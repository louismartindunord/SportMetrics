# %%
import pandas as pd 
import psycopg2
from dotenv import load_dotenv
import os 
import time
from datetime import datetime, timedelta

# %%
load_dotenv()
DATABASE = os.getenv("DATABASE")
HOST = os.getenv("HOST")
USER = os.getenv("USER")
PASSWORD = os.getenv("PASSWORD")
PORT = os.getenv("PORT")
connection = psycopg2.connect(
    host=HOST, database=DATABASE, user=USER, password=PASSWORD
)

# %%
cursor = connection.cursor()

# %% [markdown]
# ## Get all_musculation rows for a user

# %%
get_all_sport_rows_for_user = """
SELECT * FROM sport_rows 
WHERE user_id = %s
"""
user = 19

# %%
cursor.execute(get_all_sport_rows_for_user, (user,))
data_sport = cursor.fetchall()

# %%
data_sport = pd.DataFrame(data_sport, columns=["date","sport","exercice","duree","commentaire","id","user_id"])

# %%
data_sport.head()
# Out:
#          date   sport         exercice  duree  \
# 0  2024-02-24  Cardio  Vélo Elliptique   30.0
# 1  2024-02-24  Cardio  Cross Trainning   30.0
# 2  2024-02-24  Cardio           Tennis   60.0
# 3  2024-02-03  Cardio  Cross Trainning    NaN
# 4  2024-04-03  Cardio           Tennis   60.0
#
#                                          commentaire   id  user_id
# 0                                               None   26       19
# 1                                               None   27       19
# 2                                               None   28       19
# 3  20 pompes \n20 ballons mur en équilibres \n12 ...   95       19
# 4                                               None  143       19

# %%
get_all_musculation_rows_for_user = """
SELECT * FROM sport_rows 
WHERE user_id = %s
"""
user = 19

# %% [markdown]
# ## Get all_sport rows for a user

# %%
get_all_musculation_rows_for_user = """
SELECT * FROM musculation_rows 
WHERE user_id = %s
"""
user = 19

# %%
cursor.execute(get_all_musculation_rows_for_user, (user,))
data_musculation = cursor.fetchall()

# %%
data_musculation = pd.DataFrame(data_musculation, columns=["date","seance","exercice","poid","nombre_repetion","commentaire","user_id"])

# %%
all_sport = pd.concat([data_sport, data_musculation],)

# %%
all_sport
# Out:
#             date   sport                       exercice  duree  \
# 0     2024-02-24  Cardio                Vélo Elliptique   30.0
# 1     2024-02-24  Cardio                Cross Trainning   30.0
# 2     2024-02-24  Cardio                         Tennis   60.0
# 3     2024-02-03  Cardio                Cross Trainning    NaN
# 4     2024-04-03  Cardio                         Tennis   60.0
# ...          ...     ...                            ...    ...
# 1227  2024-07-18     NaN                 Back Extension    NaN
# 1228  2024-07-18     NaN  Développé Couché Prise Serrée    NaN
# 1229  2024-07-18     NaN  Développé Couché Prise Serrée    NaN
# 1230  2024-07-18     NaN  Développé Couché Prise Serrée    NaN
# 1231  2024-07-18     NaN  Développé Couché Prise Serrée    NaN
#
#                                             commentaire     id  user_id  \
# 0                                                  None   26.0       19
# 1                                                  None   27.0       19
# 2                                                  None   28.0       19
# 3     20 pompes \n20 ballons mur en équilibres \n12 ...   95.0       19
# 4                                                  None  143.0       19
# ...                                                 ...    ...      ...
# 1227                                               None    NaN       19
# 1228                                               None    NaN       19
# 1229                                               None    NaN       19
# 1230                                               None    NaN       19
# 1231                                               None    NaN       19
#
#             seance  poid  nombre_repetion
# 0              NaN   NaN              NaN
# 1              NaN   NaN              NaN
# 2              NaN   NaN              NaN
# 3              NaN   NaN              NaN
# 4              NaN   NaN              NaN
# ...            ...   ...              ...
# 1227  Haut du corp  10.0             10.0
# 1228  Haut du corp  45.0             10.0
# 1229  Haut du corp  45.0              8.0
# 1230  Haut du corp  45.0             10.0
# 1231  Haut du corp  45.0              8.0
#
# [1270 rows x 10 columns]

# %% [markdown]
# ### Création de 3 dataframe enfin d'avoir les données cette semaine, ce mois et cette annéee

# %%
all_sport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1270 entries, 0 to 1231
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             1269 non-null   datetime64[ns]
#  1   sport            38 non-null     object
#  2   exercice         1269 non-null   object
#  3   duree            33 non-null     float64
#  4   commentaire      34 non-null     object
#  5   id               38 non-null     float64
#  6   user_id          1270 non-null   int64
#  7   seance           1227 non-null   object
#  8   poid             1158 non-null   float64
#  9   nombre_repetion  1228 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 141.4+ KB

# %%
all_sport["date"] = pd.to_datetime(all_sport["date"])

# %%
now = pd.Timestamp.now()
last_week = now - timedelta(weeks=1)

# %%
df_last_week = all_sport[(all_sport["date"]>=  last_week) & (all_sport["date"] <= now)]

# %%
df_last_week
# Out:
# Empty DataFrame
# Columns: [date, sport, exercice, duree, commentaire, id, user_id, seance, poid, nombre_repetion]
# Index: []

# %%
last_month = now - timedelta(weeks=4)
df_last_month = all_sport[(all_sport["date"]>= last_month) & (all_sport["date"] <= now)]

# %%
df_last_month
# Out:
#            date sport                       exercice  duree commentaire  id  \
# 1035 2024-07-06   NaN               Développé Couché    NaN        None NaN
# 1036 2024-07-06   NaN               Développé Couché    NaN        None NaN
# 1037 2024-07-06   NaN               Développé Couché    NaN        None NaN
# 1038 2024-07-06   NaN               Développé Couché    NaN        None NaN
# 1039 2024-07-06   NaN               Développé Couché    NaN        None NaN
# ...         ...   ...                            ...    ...         ...  ..
# 1227 2024-07-18   NaN                 Back Extension    NaN        None NaN
# 1228 2024-07-18   NaN  Développé Couché Prise Serrée    NaN        None NaN
# 1229 2024-07-18   NaN  Développé Couché Prise Serrée    NaN        None NaN
# 1230 2024-07-18   NaN  Développé Couché Prise Serrée    NaN        None NaN
# 1231 2024-07-18   NaN  Développé Couché Prise Serrée    NaN        None NaN
#
#       user_id        seance  poid  nombre_repetion
# 1035       19     Pectoraux  60.0              7.0
# 1036       19     Pectoraux  70.0              3.0
# 1037       19     Pectoraux  70.0              3.0
# 1038       19     Pectoraux  70.0              2.0
# 1039       19     Pectoraux  60.0              7.0
# ...       ...           ...   ...              ...
# 1227       19  Haut du corp  10.0             10.0
# 1228       19  Haut du corp  45.0             10.0
# 1229       19  Haut du corp  45.0              8.0
# 1230       19  Haut du corp  45.0             10.0
# 1231       19  Haut du corp  45.0              8.0
#
# [197 rows x 10 columns]

# %%
# Calculer les dates pour le début et la fin de l'année dernière
first_day_last_year = now - pd.Timedelta(days=365)
first_day_last_year

df_last_year = all_sport[(all_sport['date'] >= first_day_last_year) & (all_sport['date'] <= now)]#
df_last_year.head()
# Out:
#         date   sport         exercice  duree  \
# 0 2024-02-24  Cardio  Vélo Elliptique   30.0
# 1 2024-02-24  Cardio  Cross Trainning   30.0
# 2 2024-02-24  Cardio           Tennis   60.0
# 3 2024-02-03  Cardio  Cross Trainning    NaN
# 4 2024-04-03  Cardio           Tennis   60.0
#
#                                          commentaire     id  user_id seance  \
# 0                                               None   26.0       19    NaN
# 1                                               None   27.0       19    NaN
# 2                                               None   28.0       19    NaN
# 3  20 pompes \n20 ballons mur en équilibres \n12 ...   95.0       19    NaN
# 4                                               None  143.0       19    NaN
#
#    poid  nombre_repetion
# 0   NaN              NaN
# 1   NaN              NaN
# 2   NaN              NaN
# 3   NaN              NaN
# 4   NaN              NaN

# %%
# Il faut maintenant que je créer 3 dataframes contennant tous les jours de la semaine du mois

# %%
df_last_week.shape[0]
# Out:
# 0

# %%
df_last_month.shape[0]
# Out:
# 197

# %%
df_last_year.shape[0]
# Out:
# 1141
